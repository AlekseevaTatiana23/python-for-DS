# %% [markdown]
# <a href="https://colab.research.google.com/github/AlekseevaTatiana23/python-for-DS/blob/main/hometask9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
adv1_df = pd.read_csv('advertising_1.csv', index_col='Number')

# %%
# вариант 2
#adv1_df = pd.read_csv('advertising_1.csv')
#adv1_df = adv1_df.set_index('Number')

# %%
adv1_df.head(10)
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 5                          68.95                256.09
# 6                          80.23                193.77
# 8                          74.15                245.89
# 9                            NaN                225.58
# 10                         59.99                226.74
# 11                         88.91                208.36
# 12                           NaN                131.76
# 13                         74.53                   NaN
# 14                         69.88                183.82
# 15                         47.64                122.02
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 5          Cloned 5thgeneration orchestration              0
# 6          Monitored national standardization              0
# 8       Triple-buffered reciprocal time-frame              0
# 9               Robust logistical utilization              0
# ...

# %%
# вариант 2
#adv1_df[:10]

# %%
adv1_df.shape
# Out:
# (500, 4)

# %%
#cреднее ежедневное время
#нахождения в интернете пользователя под номером 8.
adv1_df.loc[8, 'Daily Internet Usage']
# Out:
# 245.89

# %%
# вариант 2
adv1_df.iloc[2, 1]
# Out:
# 245.89

# %%
adv2_df = pd.read_csv('advertising_2.csv', index_col='Number')

# %%
# Отображение пользователей с номерами с 533 по 536
adv2_df.loc[533:536]
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 533                        46.61                   NaN
# 534                          NaN                162.03
# 535                        65.10                118.10
# 536                        53.44                   NaN
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 533             Ergonomic methodical encoding              1
# 534         Compatible dedicated productivity              0
# 535            Up-sized real-time methodology              1
# 536     Up-sized next generation architecture              1

# %%
# вариант 2 (приоритет)
adv2_df.loc[533:536, :]
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 533                        46.61                   NaN
# 534                          NaN                162.03
# 535                        65.10                118.10
# 536                        53.44                   NaN
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 533             Ergonomic methodical encoding              1
# 534         Compatible dedicated productivity              0
# 535            Up-sized real-time methodology              1
# 536     Up-sized next generation architecture              1

# %%
# вариант 3
adv2_df.iloc[3:7]
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 533                        46.61                   NaN
# 534                          NaN                162.03
# 535                        65.10                118.10
# 536                        53.44                   NaN
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 533             Ergonomic methodical encoding              1
# 534         Compatible dedicated productivity              0
# 535            Up-sized real-time methodology              1
# 536     Up-sized next generation architecture              1
